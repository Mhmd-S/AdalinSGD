# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import adalineSGD
from matplotlib.colors import ListedColormap

# %%
s = 'https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data'

df = pd.read_csv(s, header=None, encoding='utf-8')

# %%
# Get the first 100 rows and four coluns
y = df.iloc[0:200, 4].values
# Filter
y = np.where(y=='Iris-setosa', 0 , 1)

# %%
X = df.iloc[0:200, [0,2]].values

# %%
# PLot values
plt.scatter(X[:50, 0], X[:50, 1], color='red', marker='o', label='Setosa')
plt.scatter(X[50:100, 0], X[50:100, 1], color='blue', marker='s', label='Veriscolor')
plt.xlabel('Sepal length [cm]')
plt.ylabel('Petal length [cm]')
plt.legend(loc='upper left')
plt.show()

# %%
# Applying standardization feature scaling. 
mean_x1 = np.mean(X[:, 0])
mean_x2 = np.mean(X[:, 1])
std_x1 = np.std(X[:, 0])
std_x2 = np.std(X[:, 1])

X[:,0] = X[:,0] - mean_x1 / std_x1
X[:,1] = X[:,1] - mean_x2 / std_x2

# %%
ada = adalineSGD.Adaline(X, y)

ada.fit(100, True)

# %%
plt.plot(ada.losses_avg)
print(ada.losses_avg)
# Out:
# [0.05760662732073928, 0.02971185354941476, 0.02866878810602588, 0.028743771596059033, 0.02844669714145418, 0.028296986969680357, 0.02817953499782594, 0.02798444679188567, 0.027853686793601947, 0.02746058034220503, 0.027861254199492525, 0.027484092544157252, 0.02770750726221729, 0.02752759831386793, 0.027548502037368704, 0.027438094607239585, 0.027237050747661175, 0.027348498896938262, 0.027905952591892658, 0.02749766842946357, 0.026976878752274055, 0.027170144196919033, 0.026958917160555592, 0.026984914966441953, 0.027395771044810033, 0.026808989475370235, 0.02731566966538752, 0.027242437936889623, 0.02688991577468035, 0.026712343595801796, 0.02721873827755637, 0.026921821910293523, 0.02685718867476338, 0.026782566496302788, 0.02678267935561477, 0.026911009166521407, 0.02656460952445247, 0.027428909799277024, 0.026875690701143422, 0.026744426915137863, 0.02692450128970356, 0.02664040037771576, 0.026762335538553537, 0.02665289141635954, 0.02692614633156373, 0.026630211182185237, 0.026708545008619074, 0.02650129524023767, 0.026350661248954816, 0.02705716993848688, 0.026588349193307253, 0.026703163496032842, 0.026674631074608667, 0.02658346609017994, 0.026534410082142752, 0.02654511787496824, 0.026386344502524514, 0.026845374429709683, 0.0268926119644767, 0.026291456261247726, 0.026704844655279232, 0.026792928459635632, 0.026390270750780993, 0.026907189958096964, 0.02646679082395432, 0.02662763373111425, 0.026413009902762127, 0.026411849922448674, 0.026808291843760244, 0.026558100288722016, 0.026647679979700276, 0.02629579730667414, 0.026660772810209402, 0.026505920375004197, 0.026621894770592736, 0.026367587838688082, 0.026277997577757044, 0.026949180755632476, 0.02642782013043317, 0.026668484510290073, 0.026334493549090687, 0.026431387039316242, 0.026430431014473916, 0.026308759614720876, 0.026397888286748317, 0.026209102933712796, 0.026375637641744037, 0.026433207977876252, 0.02627741816733428, 0.02629287015206964, 0.02676831397774284, 0.02632788965825896, 0.026469414892370785, 0.026876697985688373, 0.026378660676288756, 0.02657893638064033, 0.026472471875850726, 0.02640537676349064, 0.02630331825210448, 0.026316573831996436]

# %%
ada.test(X,y)
# Out:
# Incorrect Prediction: 1, Target: 0, Input: [-2.48024256 -0.63739226]
# Incorrect Prediction: 1, Target: 0, Input: [-2.48024256 -0.73739226]
# Incorrect Prediction: 1, Target: 0, Input: [-2.68024256 -0.73739226]
# Incorrect Prediction: 1, Target: 0, Input: [-2.18024256 -0.63739226]
# Incorrect Prediction: 1, Target: 0, Input: [-2.28024256 -0.53739226]
# Incorrect Prediction: 1, Target: 0, Input: [-2.28024256 -0.73739226]
# Incorrect Prediction: 1, Target: 0, Input: [-2.78024256 -1.03739226]
# Incorrect Prediction: 1, Target: 0, Input: [-1.98024256 -0.43739226]
# Incorrect Prediction: 1, Target: 0, Input: [-2.28024256 -0.23739226]
# Incorrect Prediction: 1, Target: 0, Input: [-2.08024256 -0.53739226]
# Incorrect Prediction: 1, Target: 0, Input: [-2.08024256 -0.53739226]
# Incorrect Prediction: 1, Target: 0, Input: [-2.38024256 -0.53739226]
# Incorrect Prediction: 1, Target: 0, Input: [-2.28024256 -0.53739226]
# Incorrect Prediction: 1, Target: 0, Input: [-2.18024256 -0.63739226]
# Incorrect Prediction: 1, Target: 0, Input: [-2.18024256 -0.63739226]
# Incorrect Prediction: 1, Target: 0, Input: [-2.68024256 -0.83739226]
# Incorrect Prediction: 1, Target: 0, Input: [-2.58024256 -0.83739226]
# Incorrect Prediction: 1, Target: 0, Input: [-2.68024256 -0.83739226]
# Incorrect Prediction: 1, Target: 0, Input: [-2.08024256 -0.53739226]
# Incorrect Prediction: 1, Target: 0, Input: [-1.98024256 -0.23739226]
# Incorrect Prediction: 1, Target: 0, Input: [-2.28024256 -0.73739226]
# Incorrect Prediction: 1, Target: 0, Input: [-1.98024256 -0.53739226]
# Incorrect Prediction: 1, Target: 0, Input: [-2.48024256 -0.73739226]
# 0.8466666666666667
